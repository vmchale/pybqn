# %%
import bqn

# %%
def erf(z):
    return bqn.bqn('{(2÷√π)×𝕩×{(⋆-𝕩)×1(1+×)´𝕩÷1.5+↕99}×˜𝕩}',z)

# %%
import numpy as np

# %%
xs=np.arange(-2,2,0.1,dtype=np.float64)

# %%
ys=np.vectorize(erf)(xs)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/numpy/lib/_function_base_impl.py:2480: RuntimeWarning: invalid value encountered in erf (vectorized)
#   outputs = ufunc(*inputs)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(ys)
