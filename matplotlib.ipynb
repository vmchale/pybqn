# %%
import bqn

# %%
def erf(z):
    return bqn.bqn('{(2÷√π)×𝕩×{(⋆-𝕩)×1(1+×)´𝕩÷1.5+↕99}×˜𝕩}',z)

# %%
import numpy as np

# %%
x=np.arange(-2,2,0.1,dtype=np.float64)

# %%
ys=np.array([erf(z) for z in x])

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(ys)
